# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import sys
from regression_signal import rolling_regression_trading_signal, rolling_regression_trading_rule
sys.path.append('../..')
from oil_trading.EquityPerformance import equity_performance
plt.style.use("classic")
# %matplotlib inline

path = "https://github.com/queiyanglim/trading_algorithm/blob/master/oil_trading/data/daily.csv?raw=true"
df_pull = pd.read_csv(path, header=[0,1], index_col = 0)

# Prepare data
brent = df_pull.brent.CLOSE
brent.name = "brent"
wti = df_pull.wti.CLOSE
wti.name = "wti"

df_raw= pd.concat([brent, wti], axis = 1)
df = df_raw.copy()
df = df.dropna()

df.head()
# Out:
#              brent     wti
# timestamp
# 2014-05-14  110.19  102.37
# 2014-05-15  110.44  101.50
# 2014-05-16  109.75  102.02
# 2014-05-19  109.37  102.61
# 2014-05-20  109.69  102.33

# %%
#load signals
df_signal = rolling_regression_trading_signal(df_input=df, 
                                              X_name= "wti", 
                                              y_name = "brent", 
                                              update_window=20,
                                              ewm_span=170)
df_signal
# Out:
#              brent     wti     alpha       beta  r_squared  fair_spread  \
# timestamp
# 2014-06-11  109.95  104.40  0.340533  74.513127   0.222998     5.664788
# 2014-06-12  113.02  106.53  0.748040  32.398235   0.690988     5.556972
# 2014-06-13  113.41  106.91  0.906380  15.978725   0.839165     5.969840
# 2014-06-16  112.94  106.90  0.924086  14.122985   0.875441     6.007744
# 2014-06-17  113.45  106.36  1.020468   4.090005   0.907331     6.266960
# ...            ...     ...       ...        ...        ...          ...
# 2020-02-27   52.18   47.09  1.211155  -5.879715   0.913324     4.063559
# 2020-02-28   50.52   44.76  1.048059   2.408484   0.931286     4.559626
# 2020-03-02   51.90   46.75  1.028381   3.450184   0.938707     4.776994
# 2020-03-03   51.86   47.18  1.028128   3.482860   0.945654     4.809946
# 2020-03-04   51.13   46.78  1.042200   2.773790   0.951615     4.747892
#
#               signal  spread
# timestamp
# 2014-06-11  5.664788    5.55
# ...

# %%
# Create trading rule based on signal
def trend_trading_rule(df_with_signal):
    df = df_with_signal.copy()
    position = []
    pos_cache = 0 # cache position info before appending
    for i, data in df.iterrows():
        if data.spread > data.signal:
            pos_cache = 1 # If spread is widening, follow trend
        elif data.spread < data.signal:
            pos_cache = -1 # If spread is contracting, follow trende
        else:
            pos_cache = 0
        position.append({"timestamp": data.name, "position": pos_cache})
    df_pos = pd.DataFrame(position).set_index("timestamp")
    return pd.concat([df, df_pos], axis=1)

# Refresh timestamp format
# df_signal.index = pd.to_datetime(df_signal.index, format = "%Y-%m-%d")
df_signal[["spread", "fair_spread", "signal"]].plot(figsize=(20,3), grid = True)
plt.show()

# Sample strategy
# trading_strategy = rolling_regression_trading_rule
trading_strategy = trend_trading_rule

# Create position base on trading rule
df_pos = trading_strategy(df_signal)

# Equity performance
df_equity, performance = equity_performance(df_pos, X_name = "wti", y_name = "brent")
df_equity.equity.plot(figsize = (20,3), grid= True, title= "Equity Chart", color ="red")
plt.show()

df_pos[["spread", "fair_spread", "signal"]].iloc[-300:].plot(figsize=(20,3), grid = True)
plt.show()
df_pos["position"].iloc[-300:].plot(figsize=(20,3),grid = True, style = "o")
plt.show()

print(performance)
df_equity
# Out:
# {'sharpe_ratio': 0.6093576464692141, 'max_drawdown': -0.003596059673624308, 'win': 1244, 'lose': 234, 'flat': 0, 'winning_prob': 0.8416779431664412}
#              brent     wti     alpha       beta  r_squared  fair_spread  \
# timestamp
# 2014-06-11  109.95  104.40  0.340533  74.513127   0.222998     5.664788
# 2014-06-12  113.02  106.53  0.748040  32.398235   0.690988     5.556972
# 2014-06-13  113.41  106.91  0.906380  15.978725   0.839165     5.969840
# 2014-06-16  112.94  106.90  0.924086  14.122985   0.875441     6.007744
# 2014-06-17  113.45  106.36  1.020468   4.090005   0.907331     6.266960
# ...            ...     ...       ...        ...        ...          ...
# 2020-02-27   52.18   47.09  1.211155  -5.879715   0.913324     4.063559
# 2020-02-28   50.52   44.76  1.048059   2.408484   0.931286     4.559626
# 2020-03-02   51.90   46.75  1.028381   3.450184   0.938707     4.776994
# 2020-03-03   51.86   47.18  1.028128   3.482860   0.945654     4.809946
# ...

# %%
# Optimize

# Create trading rule based on signal
def trend_trading_rule(df_with_signal):
    df = df_with_signal.copy()
    position = []
    pos_cache = 0 # cache position info before appending
    for i, data in df.iterrows():
        if data.spread > data.signal:
            pos_cache = 1 # If spread is widening, follow trend
        elif data.spread < data.signal:
            pos_cache = -1 # If spread is contracting, follow trende
        else:
            pos_cache = 0
        position.append({"timestamp": data.name, "position": pos_cache})
    df_pos = pd.DataFrame(position).set_index("timestamp")
    return pd.concat([df, df_pos], axis=1)

def backtest_routine(df, update_window, ewm_span):
    df_signal = rolling_regression_trading_signal(df_input=df, 
                                                  X_name= "wti", 
                                                  y_name = "brent", 
                                                  update_window=update_window,
                                                  ewm_span=ewm_span)
    trading_strategy = trend_trading_rule
    df_pos = trading_strategy(df_signal)
    df_equity, performance = equity_performance(df_pos, X_name = "wti", y_name = "brent")
    return performance

# update_window_range = np.arange(20,200,5)
# ewm_span_range = np.arange(15,200,5)

# stats = []
# for u in update_window_range:
#     for e in ewm_span_range:
#         res = backtest_routine(df, u, e)
#         stats.append({"window": u,
#                     "ewm_window": e,
#                     "sharpe_ratio": res.get("sharpe_ratio")})
#         print("Running...", "update_window: ", u, "ewm_window: ", e, "sharpe_ratio": stats.get("sharpe_ratio"))
# Out:
#   File "<ipython-input-4-e20bda1927a8>", line 40
#     print("Running...", "update_window: ", u, "ewm_window: ", e, "sharpe_ratio": res.get("sharpe_ratio"))
#                                                                                ^
# SyntaxError: invalid syntax
